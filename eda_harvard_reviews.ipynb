# %% [markdown]
# <a href="https://colab.research.google.com/github/yasfanaaa/Yasfanara_tugasdibimbing/blob/main/eda_harvard_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/harvard_rewiews/harvard_reviews.csv')

# %%
data
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 1     2023-12-12T00:38:26-05:00            Desktop       4  review
# 2     2023-12-10T08:21:35-05:00             Mobile       3  review
# 3     2023-11-07T21:20:21-05:00            Desktop       4  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# ...                         ...                ...     ...     ...
# 3179  2010-10-29T05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   published_date      3184 non-null   object
#  1   published_platform  3184 non-null   object
#  2   rating              3184 non-null   int64
#  3   type                3184 non-null   object
#  4   helpful_votes       3184 non-null   int64
#  5   title               3184 non-null   object
#  6   text                3184 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 174.3+ KB

# %%
data.isna().sum()
# Out:
# published_date        0
# published_platform    0
# rating                0
# type                  0
# helpful_votes         0
# title                 0
# text                  0
# dtype: int64

# %%
data.describe()
# Out:
#             rating  helpful_votes
# count  3184.000000    3184.000000
# mean      4.456658       0.498744
# std       0.744024       2.819638
# min       1.000000       0.000000
# 25%       4.000000       0.000000
# 50%       5.000000       0.000000
# 75%       5.000000       1.000000
# max       5.000000     111.000000

# %%
data['rating'].describe()
# Out:
# count    3184.000000
# mean        4.456658
# std         0.744024
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: rating, dtype: float64

# %%
for column in data.columns:
    if data[column].dtype == 'object':
        # Jika kolom bertipe objek (teks), isi dengan modus (nilai yang paling sering muncul)
        mode_value = data[column].mode()[0]
        data[column] = data[column].fillna(mode_value)
    else:
        # Jika kolom numerik, isi dengan nilai rata-rata
        mean_value = data[column].mean()
        data[column] = data[column].fillna(mean_value)

# %%
data.isna().sum()
# Out:
# published_date        0
# published_platform    0
# rating                0
# type                  0
# helpful_votes         0
# title                 0
# text                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   published_date      3184 non-null   object
#  1   published_platform  3184 non-null   object
#  2   rating              3184 non-null   int64
#  3   type                3184 non-null   object
#  4   helpful_votes       3184 non-null   int64
#  5   title               3184 non-null   object
#  6   text                3184 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 174.3+ KB

# %%
# Mengecek apakah ada duplicate di seluruh kolom
check_duplicate = data.duplicated().sum()

print(f"Jumlah data yang duplikat = {check_duplicate}")
# Out:
# Jumlah data yang duplikat = 0

# %%
# Handling duplicate
data = data.drop_duplicates()

#tapi disni data saya sudah tidak ada data yang duplikat

# %%
# Mengecek duplicate setelah di-handle
handle_duplicate = data.duplicated().sum()

print(f"Jumlah data yang duplikat = {handle_duplicate}")
# Out:
# Jumlah data yang duplikat = 0
